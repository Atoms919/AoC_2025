# %%
import re
import sys

try:
    import z3
except ImportError:
    print("Error: The 'z3-solver' library is not installed.")
    print("Please install it by running: pip install z3-solver")
    sys.exit(1)

def solve_machine(line):
    # Parse target values
    target_match = re.search(r'\{([\d,]+)\}', line)
    if not target_match: return None
    target = list(map(int, target_match.group(1).split(',')))
    
    # Parse buttons
    content = line.split('}')[0]
    button_matches = re.findall(r'\(([\d,]+)\)', content)
    
    s = z3.Optimize()
    x = [z3.Int(f'btn_{i}') for i in range(len(button_matches))]
    
    for var in x:
        s.add(var >= 0)
        
    for i in range(len(target)):
        eqn = 0
        for j, btn_str in enumerate(button_matches):
            indices = list(map(int, btn_str.split(',')))
            if i in indices:
                eqn += x[j]
        s.add(eqn == target[i])
        
    total_presses = z3.Sum(x)
    s.minimize(total_presses)
    
    if s.check() == z3.sat:
        return s.model().eval(total_presses).as_long()
    return None

def main():
    filename = 'input.txt'
    total_clicks = 0
    
    try:
        with open(filename, 'r') as f:
            lines = [line for line in f.readlines() if line.strip()]
            
        total_machines = len(lines)
        
        for i, line in enumerate(lines, 1):
            clicks = solve_machine(line)
            
            if clicks is not None:
                print(f"Processing goal {i}/{total_machines}... Success! Clicks: {clicks}")
                total_clicks += clicks
            else:
                print(f"Processing goal {i}/{total_machines}... Failed (No solution)")
                
        print(f"\nTotal minimum button presses required: {total_clicks}")
        
    except FileNotFoundError:
        print(f"Error: Could not find '{filename}' in the current directory.")

if __name__ == "__main__":
    main()
# Out:
# Processing goal 1/175... Success! Clicks: 118
# Processing goal 2/175... Success! Clicks: 83
# Processing goal 3/175... Success! Clicks: 144
# Processing goal 4/175... Success! Clicks: 59
# Processing goal 5/175... Success! Clicks: 173
# Processing goal 6/175... Success! Clicks: 239
# Processing goal 7/175... Success! Clicks: 59
# Processing goal 8/175... Success! Clicks: 175
# Processing goal 9/175... Success! Clicks: 128
# Processing goal 10/175... Success! Clicks: 54
# Processing goal 11/175... Success! Clicks: 225
# Processing goal 12/175... Success! Clicks: 170
# Processing goal 13/175... Success! Clicks: 227
# Processing goal 14/175... Success! Clicks: 267
# Processing goal 15/175... Success! Clicks: 130
# Processing goal 16/175... Success! Clicks: 54
# Processing goal 17/175... Success! Clicks: 40
# Processing goal 18/175... Success! Clicks: 266
# Processing goal 19/175... Success! Clicks: 289
# Processing goal 20/175... Success! Clicks: 74
# Processing goal 21/175... Success! Clicks: 58
# Processing goal 22/175... Success! Clicks: 77
# Processing goal 23/175... Success! Clicks: 224
# Processing goal 24/175... Success! Clicks: 65
# Processing goal 25/175... Success! Clicks: 69
# Processing goal 26/175... Success! Clicks: 216
# Processing goal 27/175... Success! Clicks: 176
# Processing goal 28/175... Success! Clicks: 227
# Processing goal 29/175... Success! Clicks: 46
# Processing goal 30/175... Success! Clicks: 164
# Processing goal 31/175... Success! Clicks: 156
# Processing goal 32/175... Success! Clicks: 203
# Processing goal 33/175... Success! Clicks: 162
# Processing goal 34/175... Success! Clicks: 167
# Processing goal 35/175... Success! Clicks: 50
# Processing goal 36/175... Success! Clicks: 181
# Processing goal 37/175... Success! Clicks: 74
# Processing goal 38/175... Success! Clicks: 64
# Processing goal 39/175... Success! Clicks: 79
# Processing goal 40/175... Success! Clicks: 71
# Processing goal 41/175... Success! Clicks: 12
# Processing goal 42/175... Success! Clicks: 33
# Processing goal 43/175... Success! Clicks: 79
# Processing goal 44/175... Success! Clicks: 58
# Processing goal 45/175... Success! Clicks: 157
# Processing goal 46/175... Success! Clicks: 326
# Processing goal 47/175... Success! Clicks: 59
# Processing goal 48/175... Success! Clicks: 164
# Processing goal 49/175... Success! Clicks: 207
# Processing goal 50/175... Success! Clicks: 96
# Processing goal 51/175... Success! Clicks: 83
# Processing goal 52/175... Success! Clicks: 69
# Processing goal 53/175... Success! Clicks: 74
# Processing goal 54/175... Success! Clicks: 122
# Processing goal 55/175... Success! Clicks: 27
# Processing goal 56/175... Success! Clicks: 79
# Processing goal 57/175... Success! Clicks: 332
# Processing goal 58/175... Success! Clicks: 94
# Processing goal 59/175... Success! Clicks: 102
# Processing goal 60/175... Success! Clicks: 100
# Processing goal 61/175... Success! Clicks: 54
# Processing goal 62/175... Success! Clicks: 32
# Processing goal 63/175... Success! Clicks: 72
# Processing goal 64/175... Success! Clicks: 41
# Processing goal 65/175... Success! Clicks: 165
# Processing goal 66/175... Success! Clicks: 78
# Processing goal 67/175... Success! Clicks: 74
# Processing goal 68/175... Success! Clicks: 242
# Processing goal 69/175... Success! Clicks: 270
# Processing goal 70/175... Success! Clicks: 50
# Processing goal 71/175... Success! Clicks: 227
# Processing goal 72/175... Success! Clicks: 27
# Processing goal 73/175... Success! Clicks: 72
# Processing goal 74/175... Success! Clicks: 55
# Processing goal 75/175... Success! Clicks: 167
# Processing goal 76/175... Success! Clicks: 80
# Processing goal 77/175... Success! Clicks: 56
# Processing goal 78/175... Success! Clicks: 52
# Processing goal 79/175... Success! Clicks: 267
# Processing goal 80/175... Success! Clicks: 213
# Processing goal 81/175... Success! Clicks: 60
# Processing goal 82/175... Success! Clicks: 47
# Processing goal 83/175... Success! Clicks: 28
# Processing goal 84/175... Success! Clicks: 177
# Processing goal 85/175... Success! Clicks: 212
# Processing goal 86/175... Success! Clicks: 115
# Processing goal 87/175... Success! Clicks: 71
# Processing goal 88/175... Success! Clicks: 47
# Processing goal 89/175... Success! Clicks: 104
# Processing goal 90/175... Success! Clicks: 61
# Processing goal 91/175... Success! Clicks: 150
# Processing goal 92/175... Success! Clicks: 41
# Processing goal 93/175... Success! Clicks: 181
# Processing goal 94/175... Success! Clicks: 214
# Processing goal 95/175... Success! Clicks: 83
# Processing goal 96/175... Success! Clicks: 201
# Processing goal 97/175... Success! Clicks: 186
# Processing goal 98/175... Success! Clicks: 2
# Processing goal 99/175... Success! Clicks: 46
# Processing goal 100/175... Success! Clicks: 66
# Processing goal 101/175... Success! Clicks: 18
# Processing goal 102/175... Success! Clicks: 139
# Processing goal 103/175... Success! Clicks: 214
# Processing goal 104/175... Success! Clicks: 80
# Processing goal 105/175... Success! Clicks: 194
# Processing goal 106/175... Success! Clicks: 73
# Processing goal 107/175... Success! Clicks: 50
# Processing goal 108/175... Success! Clicks: 77
# Processing goal 109/175... Success! Clicks: 85
# Processing goal 110/175... Success! Clicks: 76
# Processing goal 111/175... Success! Clicks: 175
# Processing goal 112/175... Success! Clicks: 101
# Processing goal 113/175... Success! Clicks: 52
# Processing goal 114/175... Success! Clicks: 46
# Processing goal 115/175... Success! Clicks: 186
# Processing goal 116/175... Success! Clicks: 66
# Processing goal 117/175... Success! Clicks: 94
# Processing goal 118/175... Success! Clicks: 18
# Processing goal 119/175... Success! Clicks: 137
# Processing goal 120/175... Success! Clicks: 70
# Processing goal 121/175... Success! Clicks: 94
# Processing goal 122/175... Success! Clicks: 222
# Processing goal 123/175... Success! Clicks: 61
# Processing goal 124/175... Success! Clicks: 59
# Processing goal 125/175... Success! Clicks: 44
# Processing goal 126/175... Success! Clicks: 221
# Processing goal 127/175... Success! Clicks: 81
# Processing goal 128/175... Success! Clicks: 71
# Processing goal 129/175... Success! Clicks: 90
# Processing goal 130/175... Success! Clicks: 69
# Processing goal 131/175... Success! Clicks: 50
# Processing goal 132/175... Success! Clicks: 60
# Processing goal 133/175... Success! Clicks: 96
# Processing goal 134/175... Success! Clicks: 68
# Processing goal 135/175... Success! Clicks: 80
# Processing goal 136/175... Success! Clicks: 16
# Processing goal 137/175... Success! Clicks: 55
# Processing goal 138/175... Success! Clicks: 124
# Processing goal 139/175... Success! Clicks: 69
# Processing goal 140/175... Success! Clicks: 102
# Processing goal 141/175... Success! Clicks: 58
# Processing goal 142/175... Success! Clicks: 10
# Processing goal 143/175... Success! Clicks: 62
# Processing goal 144/175... Success! Clicks: 111
# Processing goal 145/175... Success! Clicks: 50
# Processing goal 146/175... Success! Clicks: 20
# Processing goal 147/175... Success! Clicks: 215
# Processing goal 148/175... Success! Clicks: 68
# Processing goal 149/175... Success! Clicks: 54
# Processing goal 150/175... Success! Clicks: 30
# Processing goal 151/175... Success! Clicks: 110
# Processing goal 152/175... Success! Clicks: 47
# Processing goal 153/175... Success! Clicks: 38
# Processing goal 154/175... Success! Clicks: 8
# Processing goal 155/175... Success! Clicks: 45
# Processing goal 156/175... Success! Clicks: 41
# Processing goal 157/175... Success! Clicks: 188
# Processing goal 158/175... Success! Clicks: 73
# Processing goal 159/175... Success! Clicks: 79
# Processing goal 160/175... Success! Clicks: 224
# Processing goal 161/175... Success! Clicks: 29
# Processing goal 162/175... Success! Clicks: 135
# Processing goal 163/175... Success! Clicks: 108
# Processing goal 164/175... Success! Clicks: 42
# Processing goal 165/175... Success! Clicks: 108
# Processing goal 166/175... Success! Clicks: 130
# Processing goal 167/175... Success! Clicks: 44
# Processing goal 168/175... Success! Clicks: 29
# Processing goal 169/175... Success! Clicks: 228
# Processing goal 170/175... Success! Clicks: 21
# Processing goal 171/175... Success! Clicks: 192
# Processing goal 172/175... Success! Clicks: 5
# Processing goal 173/175... Success! Clicks: 228
# Processing goal 174/175... Success! Clicks: 175
# Processing goal 175/175... Success! Clicks: 110
#
# Total minimum button presses required: 18960
